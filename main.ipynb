# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# Your image loading and displaying code here

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='coco8.yaml', epochs=100, imgsz=640)

# Run inference with the YOLOv8n model on the 'bus.jpg' image
results = model('path/to/bus.jpg')

# %%
from IPython.display import display

# %%
result = model.predict("archive/train/images/new1.jpg", save=True)
print(result)
print("boxes:")
for box in result[0].boxes:
    print(box)
# Out:
# image 1/1 /Users/tringuyen1803/Desktop/B351-Final-Project/archive/train/images/new1.jpg: 640x320 1 person, 79.4ms
# Speed: 2.4ms preprocess, 79.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 320)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data='coco128.yaml', epochs=1, imgsz=640)

# Run inference with the YOLOv8n model on the 'bus.jpg' image
results = model('path/to/bus.jpg')
# Out:
# YOLOv8n summary: 225 layers, 3157200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics YOLOv8.1.37 🚀 Python-3.9.6 torch-2.2.0 CPU (Apple M2)
# ...

# %%
results = model('datasets/archive/train/images/new1.jpg', save=True)
print(results)
# Out:
# image 1/1 /Users/tringuyen1803/Desktop/B351-Final-Project/datasets/archive/train/images/new1.jpg: 640x320 1 person, 1 car, 1 bus, 137.9ms
# Speed: 22.1ms preprocess, 137.9ms inference, 12.7ms postprocess per image at shape (1, 3, 640, 320)
# Results saved to runs/detect/train52
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...
